# %%
import pandas as pd
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

load_dotenv()
host = os.getenv("POSTGRE_HOST")
user = os.getenv("POSTGRE_USER")
password = os.getenv("POSTGRE_PASSWORD")
database = os.getenv("POSTGRE_DB")
conn = create_engine(f"postgresql://{user}:{password}@{host}/{database}")
print(f"postgresql://{user}:{password}@{host}/{database}")
# Out:
# postgresql://gengsu07:Gengsu!sh3r3@localhost/latihan_docker

# %%
df = pd.read_parquet(r"green_tripdata_2023-01.parquet")

# %%
df.to_sql("green_tripdata", con=conn, index=False, if_exists="replace")
# Out:
# 211

# %%
mpn, pbk, spmkp = [
    dfslice[dfslice["ket"].isin(["MPN", "SPM"])],
    dfslice[dfslice["ket"].isin(["PBK KIRIM", "PBK TERIMA"])],
    dfslice[dfslice["ket"].isin(["SPMKP"])],
]

# %%
pd.io.sql.get_schema(mpn, "test_table")
# Out:
# 'CREATE TABLE "test_table" (\n"nama" TEXT,\n  "kdmap" TEXT,\n  "kdbayar" TEXT,\n  "masa" INTEGER,\n  "masa2" INTEGER,\n  "tahun" INTEGER,\n  "tanggalbayar" INTEGER,\n  "bulanbayar" INTEGER,\n  "tahunbayar" INTEGER,\n  "datebayar" TIMESTAMP,\n  "nominal" REAL,\n  "ntpn" TEXT,\n  "bank" TEXT,\n  "nosk" TEXT,\n  "tahunsk" INTEGER,\n  "nospm" TEXT,\n  "ket" TEXT,\n  "npwp" TEXT\n)'

# %%
mpn.to_sql("mpn", con=conn, index=False, if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 mpn.to_sql('mpn', con=conn, index=False, if_exists='replace')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:3084, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2886 """
#    2887 Write records stored in a DataFrame to a SQL database.
#    2888
#    (...)
# ...
